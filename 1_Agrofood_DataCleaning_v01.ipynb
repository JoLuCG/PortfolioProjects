# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\jluco\Desktop\1_Python\0_Agri-food CO2\Agrofood_co2_emission_wf01.csv")
df
# Out:
#              Area Continent  Year  Savanna fires  Forest fires  Crop Residues  \
# 0     Afghanistan      Asia  1990        14.7237        0.0557       205.6077
# 1     Afghanistan      Asia  1991        14.7237        0.0557       209.4971
# 2     Afghanistan      Asia  1992        14.7237        0.0557       196.5341
# 3     Afghanistan      Asia  1993        14.7237        0.0557       230.8175
# 4     Afghanistan      Asia  1994        14.7237        0.0557       242.0494
# ...           ...       ...   ...            ...           ...            ...
# 6875     Zimbabwe    Africa  2016      1190.0089      232.5068        70.9451
# 6876     Zimbabwe    Africa  2017      1431.1407      131.1324       108.6262
# 6877     Zimbabwe    Africa  2018      1557.5830      221.6222       109.9835
# 6878     Zimbabwe    Africa  2019      1591.6049      171.0262        45.4574
# 6879     Zimbabwe    Africa  2020       481.9027       48.4197       108.3022
#
# ...

# %%
# Delete duplicate rows. None duplicates found. 
df.drop_duplicates()
# Out:
#              Area Continent  Year  Savanna fires  Forest fires  Crop Residues  \
# 0     Afghanistan      Asia  1990        14.7237        0.0557       205.6077
# 1     Afghanistan      Asia  1991        14.7237        0.0557       209.4971
# 2     Afghanistan      Asia  1992        14.7237        0.0557       196.5341
# 3     Afghanistan      Asia  1993        14.7237        0.0557       230.8175
# 4     Afghanistan      Asia  1994        14.7237        0.0557       242.0494
# ...           ...       ...   ...            ...           ...            ...
# 6875     Zimbabwe    Africa  2016      1190.0089      232.5068        70.9451
# 6876     Zimbabwe    Africa  2017      1431.1407      131.1324       108.6262
# 6877     Zimbabwe    Africa  2018      1557.5830      221.6222       109.9835
# 6878     Zimbabwe    Africa  2019      1591.6049      171.0262        45.4574
# 6879     Zimbabwe    Africa  2020       481.9027       48.4197       108.3022
#
# ...

# %%
# Values missing per column
df.isnull().sum()
# Out:
# Area                                  0
# Continent                             0
# Year                                  0
# Savanna fires                         0
# Forest fires                         62
# Crop Residues                      1358
# Rice Cultivation                      0
# Drained organic soils (CO2)           0
# Pesticides Manufacturing              0
# Food Transport                        0
# Forestland                          493
# Net Forest conversion               493
# Food Household Consumption          472
# Food Retail                           0
# On-farm Electricity Use               0
# Food Packaging                        0
# Agrifood Systems Waste Disposal       0
# Food Processing                       0
# Fertilizers Manufacturing             0
# IPPU                                743
# Manure applied to Soils             896
# Manure left on Pasture                0
# Manure Management                   896
# ...

# %%
# Delete columns accounting for missing values higher than 10% of total values.
df01 = df.drop(columns=['Crop Residues','IPPU','Manure applied to Soils','Manure Management','On-farm energy use'])
df01
# Out:
#              Area Continent  Year  Savanna fires  Forest fires  \
# 0     Afghanistan      Asia  1990        14.7237        0.0557
# 1     Afghanistan      Asia  1991        14.7237        0.0557
# 2     Afghanistan      Asia  1992        14.7237        0.0557
# 3     Afghanistan      Asia  1993        14.7237        0.0557
# 4     Afghanistan      Asia  1994        14.7237        0.0557
# ...           ...       ...   ...            ...           ...
# 6875     Zimbabwe    Africa  2016      1190.0089      232.5068
# 6876     Zimbabwe    Africa  2017      1431.1407      131.1324
# 6877     Zimbabwe    Africa  2018      1557.5830      221.6222
# 6878     Zimbabwe    Africa  2019      1591.6049      171.0262
# 6879     Zimbabwe    Africa  2020       481.9027       48.4197
#
#       Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 0             686.0000                          0.0                 11.807483
# ...

# %%
# Values missing per column
df01.isnull().sum()
# Out:
# Area                                 0
# Continent                            0
# Year                                 0
# Savanna fires                        0
# Forest fires                        62
# Rice Cultivation                     0
# Drained organic soils (CO2)          0
# Pesticides Manufacturing             0
# Food Transport                       0
# Forestland                         493
# Net Forest conversion              493
# Food Household Consumption         472
# Food Retail                          0
# On-farm Electricity Use              0
# Food Packaging                       0
# Agrifood Systems Waste Disposal      0
# Food Processing                      0
# Fertilizers Manufacturing            0
# Manure left on Pasture               0
# Fires in organic soils               0
# Fires in humid tropical forests    124
# Rural population                     0
# Urban population                     0
# Total Population - Male              0
# ...
