# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\jluco\Desktop\1_Python\0_Agri-food CO2\Agrofood_co2_emission_wf01.csv")
df
# Out:
#              Area Continent  Year  Savanna fires  Forest fires  Crop Residues  \
# 0     Afghanistan      Asia  1990          14.72          0.06         205.61
# 1     Afghanistan      Asia  1991          14.72          0.06         209.50
# 2     Afghanistan      Asia  1992          14.72          0.06         196.53
# 3     Afghanistan      Asia  1993          14.72          0.06         230.82
# 4     Afghanistan      Asia  1994          14.72          0.06         242.05
# ...           ...       ...   ...            ...           ...            ...
# 6875     Zimbabwe    Africa  2016        1190.01        232.51          70.95
# 6876     Zimbabwe    Africa  2017        1431.14        131.13         108.63
# 6877     Zimbabwe    Africa  2018        1557.58        221.62         109.98
# 6878     Zimbabwe    Africa  2019        1591.60        171.03          45.46
# 6879     Zimbabwe    Africa  2020         481.90         48.42         108.30
#
# ...

# %%
# Visualization with the histogram graph
df2.plot.hist(bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Correlation between numeric columns
sns.heatmap(df.corr(), annot = True)
plt.rcParams['figure.figsize'] = (20,7)
plt.show()
# Out:
# C:\Users\jluco\AppData\Local\Temp\ipykernel_14932\3705778008.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True)

# %%
# Find outliers
df.boxplot(column = 'Average Temperature °C', figsize=(10,5))
# Out:
# <Axes: >

# %%
# What continents have the highest change in average temperature
df2 = df.groupby('Continent')['total_emission'].max()
df2
# Out:
# Continent
# Africa           702827.98
# Asia            3115113.75
# Europe           524473.95
# North America   1034912.87
# Oceania          259432.61
# South America   1522721.61
# Name: total_emission, dtype: float64

# %%
# Adding details to the graph
df2.plot(kind = 'line', title = 'Average temperature by Continent', xlabel = 'Continent', ylabel = 'Temperature-Celcius')
# Out:
# <Axes: title={'center': 'Average temperature by Continent'}, xlabel='Continent', ylabel='Temperature-Celcius'>

# %%
# Visualization with bar graph
df2.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
# Visualization with horizontal bar graph
df2.plot.barh()
# Out:
# <Axes: ylabel='Continent'>

# %%
# Visualization with the histogram graph
df2.plot.hist(bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Visualization with the area graph
df2.plot.area()
# Out:
# <Axes: xlabel='Continent'>

# %%
# Visualization with the pie graph
df2.plot.pie(y='total_emission', figsize = (10,6))
# Out:
# <Axes: ylabel='total_emission'>
